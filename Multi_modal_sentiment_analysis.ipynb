# %%
from google.colab import drive
import pandas as pd

# Mount the Google Drive to Colab
import os
folder_path = '/content'
os.chdir(folder_path)

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'imgs.zip',
#  'data - Copy.csv',
#  'drive',
#  'train.py',
#  'data.py',
#  'model.py',
#  'sample_data']

# %%
# !unzip  '/content/drive/MyDrive/multimodal sentiment analysis/Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main.zip'
# Out:
# Archive:  /content/drive/MyDrive/multimodal sentiment analysis/Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main.zip
# 8f5533144c13edfbb8c3e09e0e456592c9b4f09c
#    creating: Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main/
#   inflating: Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main/README.md
#   inflating: Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main/data.py
#   inflating: Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main/model.py
#   inflating: Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main/requirements.txt
#   inflating: Transfer-Learning-with-Joint-Fine-Tuning-for-Multimodal-Sentiment-Analysis-main/train.py

# %%
import os
os.mkdir('imgs')

# %%
# !unzip '/content/imgs new.zip' -d '/content/imgs/'
# Out:
# Archive:  /content/imgs new.zip
#   inflating: /content/imgs/1.jpg
#   inflating: /content/imgs/10.jpg
#   inflating: /content/imgs/100.jpg
#   inflating: /content/imgs/1000.jpg
#   inflating: /content/imgs/1001.jpg
#   inflating: /content/imgs/1002.jpg
#   inflating: /content/imgs/1003.jpg
#   inflating: /content/imgs/1004.jpg
#   inflating: /content/imgs/1005.jpg
#   inflating: /content/imgs/1006.jpg
#   inflating: /content/imgs/1007.jpg
#   inflating: /content/imgs/1008.jpg
#   inflating: /content/imgs/1009.jpg
#   inflating: /content/imgs/101.jpg
#   inflating: /content/imgs/1010.jpg
#   inflating: /content/imgs/1011.jpg
#   inflating: /content/imgs/1012.jpg
#   inflating: /content/imgs/1013.jpg
#   inflating: /content/imgs/1014.jpg
#   inflating: /content/imgs/1015.jpg
#   inflating: /content/imgs/1016.jpg
#   inflating: /content/imgs/1017.jpg
#   inflating: /content/imgs/1018.jpg
#   inflating: /content/imgs/1019.jpg
#   inflating: /content/imgs/102.jpg
# ...

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.2/160.2 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.3/362.3 kB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.2/156.2 kB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 22.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 27.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -U torchtext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 54.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 53.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 15.2 MB/s eta 0:00:00
# ...

# %%
# !python  train.py  --wandb='Multimodal Sentiment analysis' --dataset='mvsa'
# Out:
# 2023-04-16 20:40:33.111658: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using custom data configuration default-4c3c32e040d972b0
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-4c3c32e040d972b0/0.0.0/51cce309a08df9c4d82ffd9363bbe090bf173197fc01a71b034e8594995a1a58)
# 100% 1/1 [00:00<00:00, 759.70it/s]
# ...

# %%
3!python wandb login --relogin
# Out:
# python3: can't open file '/content/wandb': [Errno 2] No such file or directory
